# %% [markdown]
# <a href="https://colab.research.google.com/github/IagoMagalhaes23/BBP0142---ESTAGIO-DE-DOCENCIA-I/blob/master/Analise_de_dados_Homic%C3%ADdios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Análise exploratória de dados**
# - **Professor:** Iális Cavalcante
# - **Monitor:** Iago Magalhães
# - **Disciplina:** Ciência de dados
# - **Curso:** Engenharia da Computação
# - **Descrição:**
# Que tal analisar um dataset com índices de homicídios em todo o mundo? Analisar informações do mundo real e compreender e extrair informações importantes para melhoria do nosso mundo?
# Neste notebook iremos utilizar a biblioteca **Pandas** para obter inshigts importantes e entender o comportamento de taxas de homicídios pelo mundo.

# %% [markdown]
# ##Importações

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Leitura do dataset

# %%
dataset = pd.read_excel('/content/data_cts_intentional_homicide.xlsx')

# %%
dataset.head(5)
# Out:
#   Iso3_code      Country    Region                        Subregion  \
# 0       ARM      Armenia      Asia                     Western Asia
# 1       CHE  Switzerland    Europe                   Western Europe
# 2       COL     Colombia  Americas  Latin America and the Caribbean
# 3       CZE      Czechia    Europe                   Eastern Europe
# 4       DEU      Germany    Europe                   Western Europe
#
#                                            Indicator       Dimension  \
# 0  Persons arrested/suspected for intentional hom...  by citizenship
# 1  Persons arrested/suspected for intentional hom...  by citizenship
# 2  Persons arrested/suspected for intentional hom...  by citizenship
# 3  Persons arrested/suspected for intentional hom...  by citizenship
# 4  Persons arrested/suspected for intentional hom...  by citizenship
#
#             Category   Sex    Age  Year Unit of measurement    VALUE Source
# ...

# %% [markdown]
# ##Obtendo informações básicas

# %%
dataset.shape
# Out:
# (113634, 13)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113634 entries, 0 to 113633
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Iso3_code            113634 non-null  object
#  1   Country              113634 non-null  object
#  2   Region               113634 non-null  object
#  3   Subregion            113634 non-null  object
#  4   Indicator            113634 non-null  object
#  5   Dimension            113634 non-null  object
#  6   Category             113634 non-null  object
#  7   Sex                  113634 non-null  object
#  8   Age                  113634 non-null  object
#  9   Year                 113634 non-null  int64
#  10  Unit of measurement  113634 non-null  object
#  11  VALUE                113634 non-null  float64
#  12  Source               113634 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 11.3+ MB

# %%
dataset.tail()
# Out:
#         Iso3_code         Country          Region       Subregion  \
# 113629  M49_W_EUR  Western Europe  Western Europe  Western Europe
# 113630  M49_W_EUR  Western Europe  Western Europe  Western Europe
# 113631  M49_W_EUR  Western Europe  Western Europe  Western Europe
# 113632  M49_W_EUR  Western Europe  Western Europe  Western Europe
# 113633  M49_W_EUR  Western Europe  Western Europe  Western Europe
#
#                                                 Indicator Dimension Category  \
# 113629  Victims of Intentional Homicide - Regional Est...     Total    Total
# 113630  Victims of Intentional Homicide - Regional Est...     Total    Total
# 113631  Victims of Intentional Homicide - Regional Est...     Total    Total
# 113632  Victims of Intentional Homicide - Regional Est...     Total    Total
# 113633  Victims of Intentional Homicide - Regional Est...     Total    Total
#
#          Sex    Age  Year          Unit of measurement     VALUE  \
# ...

# %%
dataset.describe()
# Out:
#                 Year          VALUE
# count  113634.000000  113634.000000
# mean     2014.684487     726.510782
# std         6.144394    9814.672849
# min      1990.000000       0.000000
# 25%      2012.000000       0.261888
# 50%      2016.000000       2.609235
# 75%      2019.000000      21.000000
# max      2022.000000  457945.484991

# %% [markdown]
# ##Limpeza dos dados

# %%
dataset.isnull().sum()
# Out:
# Iso3_code              0
# Country                0
# Region                 0
# Subregion              0
# Indicator              0
# Dimension              0
# Category               0
# Sex                    0
# Age                    0
# Year                   0
# Unit of measurement    0
# VALUE                  0
# Source                 0
# dtype: int64

# %% [markdown]
# ##Questionamentos
# - Informações do dataset:

# %%
countrys = dataset['Country'].unique()
print(countrys)
# Out:
# ['Armenia' 'Switzerland' 'Colombia' 'Czechia' 'Germany' 'Finland'
#  'Guatemala' 'Honduras' 'Hungary' 'Iceland' 'Italy' 'Japan' 'Sri Lanka'
#  'Lithuania' 'Mongolia' 'Norway' 'Serbia' 'Slovakia' 'Slovenia' 'Türkiye'
#  'Antigua and Barbuda' 'Austria' 'Belgium' 'Belize'
#  'Bolivia (Plurinational State of)' 'Bhutan' 'Denmark' 'France' 'Greece'
#  'China, Macao Special Administrative Region' 'Russian Federation'
#  'Uzbekistan' 'Albania' 'Azerbaijan' 'Barbados' 'Chile' 'Spain' 'Grenada'
#  'Guyana' 'Croatia' 'Liechtenstein' 'Latvia' 'Montenegro' 'Panama'
#  'Dominica' 'Jordan' 'Saint Kitts and Nevis' 'Saint Lucia' 'Mexico'
#  'Malta' 'Oman' 'Trinidad and Tobago' 'Bulgaria' 'Bahamas' 'Canada'
#  'Dominican Republic' 'El Salvador' 'Uruguay' 'Bosnia and Herzegovina'
#  'Saint Vincent and the Grenadines' 'Ecuador' 'Holy See' 'Morocco'
#  'Mauritius' 'Aruba' 'Anguilla' 'Australia' 'Belarus' 'Bermuda' 'Brazil'
#  'Costa Rica' 'Cayman Islands' 'Cyprus' 'Egypt' 'Estonia' 'Fiji'
# ...

# %%
subregioes = ['Western Asia', 'Western Europe', 'Latin America and the Caribbean',
 'Eastern Europe', 'Northern Europe', 'Southern Europe', 'Eastern Asia',
 'Southern Asia', 'Central Asia', 'Northern America', 'Northern Africa',
 'Sub-Saharan Africa', 'Australia and New Zealand', 'Melanesia',
 'South-eastern Asia', 'Micronesia', 'Polynesia', 'Oceania', 'Asia', 'Europe', 'Americas', 'Africa', 'All Oceania']

dataset = dataset[~dataset['Country'].isin(subregioes)]

# %%
# Encontrar o índice das linhas onde a coluna 'Country' tem o valor 'World'
indices_to_drop = dataset[dataset['Country'] == 'World'].index

# Usar drop para remover essas linhas
dataset = dataset.drop(indices_to_drop)

# %%
# Encontrar o índice das linhas onde a coluna 'Region' tem o valor 'World'
indices_to_drop = dataset[dataset['Region'] == 'World'].index

# Usar drop para remover essas linhas
dataset = dataset.drop(indices_to_drop)

# %%
dataset.shape
# Out:
# (111390, 13)

# %% [markdown]
# ###Quais países apresentam as 10 maiores índices de homicídios nos últimos 5 anos?

# %%
sub = dataset['Subregion'].unique()
print(sub)
# Out:
# ['Western Asia' 'Western Europe' 'Latin America and the Caribbean'
#  'Eastern Europe' 'Northern Europe' 'Southern Europe' 'Eastern Asia'
#  'Southern Asia' 'Central Asia' 'Northern America' 'Northern Africa'
#  'Sub-Saharan Africa' 'Australia and New Zealand' 'Melanesia'
#  'South-eastern Asia' 'Micronesia' 'Polynesia' 'Africa' 'Americas' 'Asia'
#  'Europe']

# %%
subregioes = ['Western Asia', 'Western Europe', 'Latin America and the Caribbean',
 'Eastern Europe', 'Northern Europe', 'Southern Europe', 'Eastern Asia',
 'Southern Asia', 'Central Asia', 'Northern America', 'Northern Africa',
 'Sub-Saharan Africa', 'Australia and New Zealand', 'Melanesia',
 'South-eastern Asia', 'Micronesia', 'Polynesia', 'Oceania', 'All Africa', 'All Americas', 'All Asia']

dataset = dataset[~dataset['Country'].isin(subregioes)]

# %%
homicidios = dataset[dataset['Year'] > 2017]

homicidios = homicidios.groupby("Country")[["VALUE"]].sum().reset_index()
homicidios = homicidios.sort_values(by='VALUE', ascending=False).head(10)

# %%
homicidios
# Out:
#                       Country         VALUE
# 90                     Mexico  1.491660e+06
# 34                   Colombia  6.365779e+05
# 152  United States of America  5.939964e+05
# 24                     Brazil  5.256505e+05
# 66                      India  3.875916e+05
# 118        Russian Federation  3.257109e+05
# 68        Iraq (Central Iraq)  2.197132e+05
# 63                   Honduras  1.573056e+05
# 3                  All Europe  1.445955e+05
# 59                  Guatemala  1.379711e+05

# %% [markdown]
# ###Quais países apresentam os 10 maiores índices de homicídios de mulheres em 2022?

# %%
homicidios_mulheres2022 = dataset[dataset['Year'] == 2022]

homicidios_mulheres2022 = homicidios_mulheres2022.groupby("Country")[["VALUE"]].sum().reset_index()
homicidios_mulheres2022 = homicidios_mulheres2022.sort_values(by='VALUE', ascending=False).head(10)

# %%
homicidios_mulheres2022
# Out:
#                      Country          VALUE
# 41                    Mexico  256801.286701
# 16                  Colombia  126129.786610
# 23                   Ecuador   52611.167446
# 70  United States of America   43205.220282
# 68                   Türkiye   22446.507740
# 3                  Argentina   17199.591154
# 13                     Chile   16113.792161
# 34                   Jamaica   14719.457812
# 22        Dominican Republic   11419.991611
# 36                     Kenya   10520.622952

# %% [markdown]
# ###Quais as regiões com mais homicídios?

# %%
region = dataset['Region'].unique()
print(region)
# Out:
# ['Asia' 'Europe' 'Americas' 'Africa' 'Oceania']

# %%
subregioes = ['Western Asia', 'Western Europe', 'Latin America and the Caribbean',
 'Eastern Europe', 'Northern Europe', 'Southern Europe', 'Eastern Asia',
 'Southern Asia', 'Central Asia', 'Northern America', 'Northern Africa',
 'Sub-Saharan Africa', 'Australia and New Zealand', 'Melanesia',
 'South-eastern Asia', 'Micronesia', 'Polynesia' 'Oceania']

dataset = dataset[~dataset['Region'].isin(subregioes)]

# %%
regioes = dataset.groupby("Region")[["VALUE"]].sum().reset_index()
regioes = regioes.sort_values(by='VALUE', ascending=False).head(5)

# %%
regioes
# Out:
#      Region         VALUE
# 1  Americas  1.481766e+07
# 2      Asia  5.906821e+06
# 3    Europe  5.052105e+06
# 0    Africa  1.507125e+06
# 4   Oceania  4.871614e+04

# %%
regioes.plot.bar(x='Region', y='VALUE')
# Out:
# <Axes: xlabel='Region'>

# %%
regioes.plot.scatter(x='Region', y='VALUE')
# Out:
# <Axes: xlabel='Region', ylabel='VALUE'>

# %%
regioes.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ###Quais países com menor número de homicídios?

# %%
menos_homicidios = dataset.groupby("Country")[["VALUE"]].sum().reset_index()
menos_homicidios = menos_homicidios.sort_values(by='VALUE').head(10)

# %%
menos_homicidios
# Out:
#                               Country      VALUE
# 60                      Faroe Islands   0.000000
# 50                           Djibouti   0.000000
# 79                           Holy See   0.000000
# 42                       Cook Islands   4.117609
# 69                          Gibraltar   4.198772
# 120  Micronesia (Federated States of)   4.705929
# 203                           Vanuatu  11.903921
# 121                            Monaco  12.322890
# 163                        San Marino  12.576962
# 156                      Saint Helena  18.736786

# %%
menos_homicidios.plot.bar(x='Country', y='VALUE')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ###Quais países com menor número de morte de mulheres?

# %%
homicidios_mulheres = dataset.groupby("Country")[["VALUE"]].sum().reset_index()
homicidios_mulheres = homicidios_mulheres.sort_values(by='VALUE').head(10)

# %%
homicidios_mulheres
# Out:
#                               Country      VALUE
# 60                      Faroe Islands   0.000000
# 50                           Djibouti   0.000000
# 79                           Holy See   0.000000
# 42                       Cook Islands   4.117609
# 69                          Gibraltar   4.198772
# 120  Micronesia (Federated States of)   4.705929
# 203                           Vanuatu  11.903921
# 121                            Monaco  12.322890
# 163                        San Marino  12.576962
# 156                      Saint Helena  18.736786

# %% [markdown]
# ###Quais as subregiões com maior número de homicídios?

# %%
continentes = ['Americas', 'Africa', 'Asia', 'Europe']

dataset = dataset[~dataset['Subregion'].isin(continentes)]

# %%
subregions = dataset.groupby("Subregion")[["VALUE"]].sum().reset_index()
subregions = subregions.sort_values(by='VALUE', ascending=False).head(5)

# %%
subregions
# Out:
#                           Subregion         VALUE
# 4   Latin America and the Caribbean  1.240230e+07
# 12                    Southern Asia  3.616994e+06
# 3                    Eastern Europe  2.817782e+06
# 8                  Northern America  2.415360e+06
# 14               Sub-Saharan Africa  1.353438e+06

# %% [markdown]
# ###Indentifique o pais com maior número de homicídios em cada continente em 2020

# %%
regioes = dataset[(dataset['Year'] == 2020) & (dataset['Region'] == 'Asia')]

regioes = regioes.groupby("Country")[["VALUE"]].sum().reset_index()
regioes = regioes.sort_values(by='VALUE', ascending=False).head(1)

# %%
regioes
# Out:
#    Country         VALUE
# 10   India  93954.608171

# %%
regioes = dataset[(dataset['Year'] == 2020) & (dataset['Region'] == 'Europe')]

regioes = regioes.groupby("Country")[["VALUE"]].sum().reset_index()
regioes = regioes.sort_values(by='VALUE', ascending=False).head(1)

# %%
regioes
# Out:
#                Country          VALUE
# 33  Russian Federation  103990.988833

# %%
regioes = dataset[(dataset['Year'] == 2020) & (dataset['Region'] == 'Africa')]

regioes = regioes.groupby("Country")[["VALUE"]].sum().reset_index()
regioes = regioes.sort_values(by='VALUE', ascending=False).head(1)

# %%
regioes
# Out:
#          Country         VALUE
# 14  South Africa  20005.964873

# %%
regioes = dataset[(dataset['Year'] == 2020) & (dataset['Region'] == 'Oceania')]

regioes = regioes.groupby("Country")[["VALUE"]].sum().reset_index()
regioes = regioes.sort_values(by='VALUE', ascending=False).head(1)

# %%
regioes
# Out:
#      Country        VALUE
# 0  Australia  1542.689897

# %%
regioes = dataset[(dataset['Year'] == 2020) & (dataset['Region'] == 'Americas')]

regioes = regioes.groupby("Country")[["VALUE"]].sum().reset_index()
regioes = regioes.sort_values(by='VALUE', ascending=False).head(1)

# %%
regioes
# Out:
#    Country          VALUE
# 24  Mexico  320434.185574

# %% [markdown]
# ###Qual o país com mais violento para as mulheres em 2021?

# %%
homicidios_mulheres2021 = dataset[dataset['Year'] == 2021]

homicidios_mulheres2021 = homicidios_mulheres2021.groupby("Country")[["VALUE"]].sum().reset_index()
homicidios_mulheres2021 = homicidios_mulheres2021.sort_values(by='VALUE', ascending=False).head(1)

# %%
homicidios_mulheres2021
# Out:
#    Country          VALUE
# 68  Mexico  299702.194635

# %% [markdown]
# ###Qual o país com maior valor de 'indicador: Victims of intentional homicide'?

# %%
vih = dataset[dataset['Indicator'] == 'Victims of intentional homicide']

vih = vih.groupby("Country")[["VALUE"]].sum().reset_index()
vih = vih.sort_values(by='VALUE', ascending=False).head(1)

# %%
vih
# Out:
#    Country         VALUE
# 26  Brazil  3.097339e+06

# %% [markdown]
# ###Qual a média de homicídios no Brasil nos últimos 10 anos?

# %%
media_homicidios = dataset[(dataset['Year'] > 2012) & (dataset['Country'] == 'Brazil')]

# %%
print(len(media_homicidios))
# Out:
# 118

# %%
print(media_homicidios)
# Out:
#        Iso3_code Country    Region                        Subregion  \
# 4238         BRA  Brazil  Americas  Latin America and the Caribbean
# 4373         BRA  Brazil  Americas  Latin America and the Caribbean
# 4504         BRA  Brazil  Americas  Latin America and the Caribbean
# 4634         BRA  Brazil  Americas  Latin America and the Caribbean
# 4765         BRA  Brazil  Americas  Latin America and the Caribbean
# ...          ...     ...       ...                              ...
# 103216       BRA  Brazil  Americas  Latin America and the Caribbean
# 103269       BRA  Brazil  Americas  Latin America and the Caribbean
# 111892       BRA  Brazil  Americas  Latin America and the Caribbean
# 111942       BRA  Brazil  Americas  Latin America and the Caribbean
# 111995       BRA  Brazil  Americas  Latin America and the Caribbean
#
#                                                 Indicator    Dimension  \
# 4238                      Victims of intentional homicide        Total
# ...

# %%
media_homicidios['VALUE'].plot.box()
# Out:
# <Axes: >

# %%
media_homicidios = media_homicidios.groupby("Country")[["VALUE"]].sum().reset_index()

# %%
media_homicidios
# Out:
#   Country         VALUE
# 0  Brazil  1.125789e+06

# %%
print('Média de homicídios no Brasil nos últimos 10 anos é: {}'.format(media_homicidios['VALUE'] / 118))
# Out:
# Média de homicídios no Brasil nos últimos 10 anos é: 0    9540.588118
# Name: VALUE, dtype: float64

# %% [markdown]
# ##Referências
# - [Pandas Tutorail - Geeks for Geeks](https://www.geeksforgeeks.org/pandas-tutorial/)
# - [Data Visualization with Pandas](https://www.geeksforgeeks.org/pandas-built-in-data-visualization-ml/)
